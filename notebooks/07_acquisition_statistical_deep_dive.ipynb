# %% [markdown]
# # Acquisition quality\nThis notebook is a reproducible companion to the production outputs. The scripts under src/ are the source of truth.\n

# %%
import pandas as pd\npd.read_csv('../reports/statistics/acquisition_conversion_by_origin.csv')
