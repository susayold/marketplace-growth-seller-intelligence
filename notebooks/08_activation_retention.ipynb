# %% [markdown]
# # Activation and retention
# Use eligibility-aware retention and time-to-event outputs; recent cohorts are censored.

# %%
import pandas as pd
retention = pd.read_csv('../reports/statistics/retention_m3_ci.csv')
speed = pd.read_csv('../reports/statistics/retention_by_activation_speed.csv')
retention, speed
