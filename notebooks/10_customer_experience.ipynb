# %% [markdown]
# # Customer experience
# Late delivery comparisons use reviewed delivered orders and pair rates with effect sizes and intervals.

# %%
import pandas as pd
pd.read_csv('../reports/statistics/late_review_effect.csv')
