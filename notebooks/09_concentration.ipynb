# %% [markdown]
# # Seller value concentration
# Seller-level aggregation precedes Gini, Lorenz and top-share calculations.

# %%
import pandas as pd
pd.read_csv('../reports/statistics/concentration_statistics.csv')
