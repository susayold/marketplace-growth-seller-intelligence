# %% [markdown]
# # Acquisition quality
# Rebuilds the acquisition evidence from `reports/statistics/` and preserves the FDR boundary.

# %%
import pandas as pd
pd.read_csv('../reports/statistics/acquisition_conversion_by_origin.csv')
